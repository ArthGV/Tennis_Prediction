# %% [markdown]
# # Notebook used for data exploration

# %%
import pandas as pd

# %%
data_path = '../data/atp_matches_2024.csv'
data = pd.read_csv(data_path)

# %%
data.tourney_name.unique()
# Out:
# array(['Brisbane', 'United Cup', 'Hong Kong', 'Adelaide', 'Auckland',
#        'Australian Open', 'Montpellier', 'Cordoba', 'Dallas', 'Marseille',
#        'Delray Beach', 'Buenos Aires', 'Rotterdam', 'Doha', 'Los Cabos',
#        'Rio De Janeiro', 'Acapulco', 'Dubai', 'Santiago',
#        'Indian Wells Masters', 'Miami Masters', 'Estoril', 'Houston',
#        'Marrakech', 'Monte Carlo Masters', 'Barcelona', 'Munich',
#        'Bucharest', 'Madrid Masters', 'Rome Masters', 'Geneva', 'Lyon',
#        'Roland Garros', 's Hertogenbosch', 'Stuttgart', 'Halle',
#        "Queen's Club", 'Mallorca', 'Eastbourne', 'Wimbledon', 'Gstaad',
#        'Hamburg', 'Bastad', 'Newport', 'Atlanta', 'Kitzbuhel', 'Umag',
#        'Washington', 'Paris Olympics', 'Canada Masters',
#        'Cincinnati Masters', 'Winston-Salem', 'Us Open', 'Chengdu',
#        'Hangzhou', 'Laver Cup', 'Tokyo', 'Beijing', 'Shanghai Masters',
#        'Almaty', 'Antwerp', 'Stockholm', 'Basel', 'Vienna',
# ...

# %%
data[data['tourney_name'] == 'Adelaide'][['winner_name', 'loser_name', 'score']]
# Out:
#               winner_name               loser_name              score
# 83           Jiri Lehecka              Jack Draper        4-6 6-4 6-3
# 84            Jack Draper         Alexander Bublik         7-6(2) 6-4
# 85           Jiri Lehecka          Sebastian Korda            6-2 6-1
# 86            Jack Draper               Tommy Paul            6-1 6-4
# 87       Alexander Bublik          Lorenzo Musetti     6-3 6-7(4) 7-5
# 88        Sebastian Korda     Christopher Oconnell            6-4 6-4
# 89           Jiri Lehecka            Nicolas Jarry            6-4 7-5
# 90             Tommy Paul                Alex Bolt            6-3 6-2
# 91            Jack Draper        Miomir Kecmanovic  5-7 7-6(9) 7-6(7)
# 92        Lorenzo Musetti          Jordan Thompson            6-4 6-1
# 93       Alexander Bublik             Daniel Evans        4-6 6-2 6-1
# 94   Christopher Oconnell     Alexander Shevchenko            6-3 6-1
# ...

# %%
data
# Out:
#                             tourney_id                  tourney_name surface  \
# 0                            2024-0339                      Brisbane    Hard
# 1                            2024-0339                      Brisbane    Hard
# 2                            2024-0339                      Brisbane    Hard
# 3                            2024-0339                      Brisbane    Hard
# 4                            2024-0339                      Brisbane    Hard
# ...                                ...                           ...     ...
# 3071  2024-M-DC-2024-WG2-PO-URU-MDA-01  Davis Cup WG2 PO: URU vs MDA    Clay
# 3072  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
# 3073  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
# 3074  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
# 3075  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
#
# ...

# %%
for col in data.columns:
    print(col)
# Out:
# tourney_id
# tourney_name
# surface
# draw_size
# tourney_level
# tourney_date
# match_num
# winner_id
# winner_seed
# winner_entry
# winner_name
# winner_hand
# winner_ht
# winner_ioc
# winner_age
# loser_id
# loser_seed
# loser_entry
# loser_name
# loser_hand
# loser_ht
# loser_ioc
# loser_age
# score
# best_of
# round
# minutes
# w_ace
# w_df
# w_svpt
# w_1stIn
# w_1stWon
# w_2ndWon
# w_SvGms
# w_bpSaved
# w_bpFaced
# l_ace
# l_df
# l_svpt
# l_1stIn
# l_1stWon
# l_2ndWon
# l_SvGms
# l_bpSaved
# l_bpFaced
# winner_rank
# winner_rank_points
# loser_rank
# loser_rank_points

# %%
#Nans per columns
for col in data.columns:
    number_of_nan = data[col].isna().sum()
    if number_of_nan:
        print(f'Number of Nans in {col} : {number_of_nan}')
# Out:
# Number of Nans in winner_seed : 1782
# Number of Nans in winner_entry : 2599
# Number of Nans in winner_ht : 19
# Number of Nans in winner_age : 1
# Number of Nans in loser_seed : 2319
# Number of Nans in loser_entry : 2358
# Number of Nans in loser_ht : 50
# Number of Nans in loser_age : 1
# Number of Nans in minutes : 238
# Number of Nans in w_ace : 60
# Number of Nans in w_df : 60
# Number of Nans in w_svpt : 60
# Number of Nans in w_1stIn : 60
# Number of Nans in w_1stWon : 60
# Number of Nans in w_2ndWon : 60
# Number of Nans in w_SvGms : 61
# Number of Nans in w_bpSaved : 60
# Number of Nans in w_bpFaced : 60
# Number of Nans in l_ace : 60
# Number of Nans in l_df : 60
# Number of Nans in l_svpt : 60
# Number of Nans in l_1stIn : 60
# Number of Nans in l_1stWon : 60
# Number of Nans in l_2ndWon : 60
# Number of Nans in l_SvGms : 61
# Number of Nans in l_bpSaved : 60
# Number of Nans in l_bpFaced : 60
# Number of Nans in winner_rank : 17
# ...

# %% [markdown]
# ### Ideas
#
# - do not include name or ID
#
# - no binary predictions
# - double trainning data by players symmetry

# %% [markdown]
# #--- TOURNEY ---
# tourney_name
# surface
# draw_size
# tourney_level
# tourney_date
#
# #--- PLAYER 1 ---
# winner_seed
# winner_entry
# winner_hand
# winner_ht
# winner_ioc
# winner_age
# winner_rank
# winner_rank_points
#
# #--- PLAYER 2 ---
# loser_seed
# loser_entry
# loser_hand
# loser_ht
# loser_ioc
# loser_age
# loser_rank
# loser_rank_points
#
# #--- MATCH ---
# best_of
# round
#
# #--- OUTCOME ---
# score

# %% [markdown]
# #TOURNEY to remove
#
# Davis
# Next Gen Finals
# United Cup
